# %%
# !pip install pandas

# %%
import pandas as pd

df = pd.read_csv("../State of Data 2021 - Dataset - Pgina1.csv")
# Out:
# /tmp/ipykernel_11026/2883021374.py:3: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../State of Data 2021 - Dataset - Pgina1.csv")

# %%
df.columns
# Out:
# Index(['('P0', 'id')', '('P1_a ', 'Idade')', '('P1_a_a ', 'Faixa idade')',
#        '('P1_b ', 'Genero')', '('P1_e ', 'Estado onde mora')',
#        '('P1_e_a ', 'uf onde mora')', '('P1_e_b ', 'Regiao onde mora')',
#        '('P1_g_b ', 'Regiao de origem')', '('P1_g_c ', 'Mudou de Estado?')',
#        '('P1_h ', 'Nivel de Ensino')',
#        ...
#        '('P8_d_g ', 'Criando e dando manutenção em ETLs, DAGs e automações de pipelines de dados.')',
#        '('P8_d_h ', 'Criando e gerenciando soluções de Feature Store e cultura de MLOps.')',
#        '('P8_d_i ', 'Criando e mantendo a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')',
#        '('P9_a ', 'Quais das iniciativas do Data Hackers que você já acessou/acompanhou?')',
#        '('P9_a_a ', 'Blog/Medium do Data Hackers')',
#        '('P9_a_b ', 'Podcast do Data Hackers')',
#        '('P9_a_d ', 'Newsletter Semanal')', '('P9_a_e ', 'Canal do Slack')',
# ...

# %%
df
# Out:
#                           ('P0', 'id')  ('P1_a ', 'Idade')  \
# 0     qkx4q0ei90wcjxnqkx4q0j3xgf0zn13s                38.0
# 1     zdl2n19yhgpnoaco6kkczdl2nwv9zwrt                39.0
# 2     vsamqp2un3q7us84mgvsams5fulsmcoh                30.0
# 3     v31ab41botodnsv31zgg4k34zzojy81l                38.0
# 4     ubhu8ntvm4xc0sfkdubhu80e973eek0k                36.0
# ...                                ...                 ...
# 2640  07nvo8cdy377a46gon207nvjebwe65zg                40.0
# 2641  01mqnby32u01pg3nuj6vipp4mc06s8pg                27.0
# 2642  01fncs8qbhl9zx01fncs8rqib2zl3d18                24.0
# 2643  075h3v2z19if04yn7o075h3vhifl38rw                38.0
# 2644  037usz1h2yip96dgil4mhj037uszw1gk                27.0
#
#      ('P1_a_a ', 'Faixa idade') ('P1_b ', 'Genero')  \
# 0                         35-39           Masculino
# 1                         35-39           Masculino
# 2                         30-34           Masculino
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.57.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (102 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# ...
#   Using cached pillow-11.2.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
# Using cached matplotlib-3.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
# Using cached contourpy-1.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...

# %%
import matplotlib.pyplot as plt

# Contagem de cada categoria de gênero
contagem_genero = df["('P1_b ', 'Genero')"].value_counts()

# Criando o gráfico de barras
contagem_genero.plot(kind='bar', color='skyblue', edgecolor='black')

# Títulos e rótulos
plt.title('Distribuição por Gênero')
plt.xlabel('Gênero')
plt.ylabel('Frequência')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
print(df.columns.tolist())
# Out:
# ["('P0', 'id')", "('P1_a ', 'Idade')", "('P1_a_a ', 'Faixa idade')", "('P1_b ', 'Genero')", "('P1_e ', 'Estado onde mora')", "('P1_e_a ', 'uf onde mora')", "('P1_e_b ', 'Regiao onde mora')", "('P1_g_b ', 'Regiao de origem')", "('P1_g_c ', 'Mudou de Estado?')", "('P1_h ', 'Nivel de Ensino')", "('P1_i ', 'Área de Formação')", "('P2_a ', 'Qual sua situação atual de trabalho?')", "('P2_b ', 'Setor')", "('P2_c ', 'Numero de Funcionarios')", "('P2_d ', 'Gestor?')", "('P2_e ', 'Cargo como Gestor')", "('P2_f ', 'Cargo Atual')", "('P2_g ', 'Nivel')", "('P2_h ', 'Faixa salarial')", "('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')", "('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')", "('P2_k ', 'Você está satisfeito na sua empresa atual?')", "('P2_l ', 'Qual o principal motivo da sua insatisfação com a empresa atual?')", "('P2_l_a ', 'Falta de oportunidade de crescimento no emprego atual')"
# ...

# %%
import seaborn as sns

# Renomear colunas 
col_genero = "('P1_b ', 'Genero')" 
col_area = "('P2_b ', 'Setor')"
col_cargo = "('P2_f ', 'Cargo Atual')"
col_salario = "('P2_h ', 'Faixa salarial')" #"('P2_o_a ', 'Remuneração/Salário')"

# Distribuição geral por gênero
genero_counts = df[col_genero].value_counts(normalize=True).sort_values(ascending=False)

plt.figure(figsize=(6, 4))
sns.barplot(x=genero_counts.index, y=genero_counts.values * 100, palette="pastel")
plt.ylabel('% do total')
plt.title('Distribuição por Gênero')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Proporção de gênero por área de atuação
area_genero = df.groupby([col_area, col_genero]).size().reset_index(name='contagem')
area_total = df.groupby(col_area).size().reset_index(name='total')
area_genero = area_genero.merge(area_total, on=col_area)
area_genero['percentual'] = 100 * area_genero['contagem'] / area_genero['total']

plt.figure(figsize=(12, 6))
sns.barplot(data=area_genero, x=col_area, y='percentual', hue=col_genero, palette="Set2")
plt.title('Proporção por Gênero em Cada Área de Atuação')
plt.ylabel('% dentro da área')
plt.xlabel('Área de Atuação')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Gênero')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_11026/2851151225.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=genero_counts.index, y=genero_counts.values * 100, palette="pastel")
